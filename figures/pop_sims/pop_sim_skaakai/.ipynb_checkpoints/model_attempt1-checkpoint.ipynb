# %%
library(IBMPopSim)

# %%
#update.packages(checkBuilt=TRUE, ask=FALSE)
#install.packages("Rcpp")
#install.packages("IBMPopSim")
#install.packages("devtools")
#install.packages("IRkernel")
#IRkernel::installspec()

# %%
pop <- data.frame("birth"=rep(0,1000), "death"=rep(NA,1000), "smurfness"=rep(0,1000))
params <- list("a" = 0.015,
               "b" = -0.09,
               "k" = 0.19)

# %%
death_event <- mk_event_individual(type = "death",
    intensity_code = 'if (I.smurfness==0)
            result = 0;
        else
            result = k;'
)

# %%
swap_event <- mk_event_individual(
    type = "swap",
    intensity_code = 'if (I.smurfness==0)
                result = a*age(I,t)+b;
            else
                result = 0;',
    kernel_code = 'I.smurfness=1;'
)

# %%
model <- mk_model(
    characteristics = get_characteristics(pop),
    events = list(death_event, swap_event),
    parameters = params)

summary(model)
# Out:
# x86_64-conda-linux-gnu-c++ -std=gnu++11 -I"/home/mrera/anaconda3/envs/r4-base/lib/R/include" -DNDEBUG -I../inst/include -fopenmp  -I"/home/mrera/anaconda3/envs/r4-base/lib/R/library/Rcpp/include" -I"/home/mrera/anaconda3/envs/r4-base/lib/R/library/IBMPopSim/include" -I"/home/mrera/anaconda3/envs/r4-base/lib/R/library/RcppArmadillo/include" -I"/tmp/RtmpPVSWLT/sourceCpp-x86_64-conda-linux-gnu-1.0.8.3" -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/mrera/anaconda3/envs/r4-base/include -I/home/mrera/anaconda3/envs/r4-base/include -Wl,-rpath-link,/home/mrera/anaconda3/envs/r4-base/lib   -fpic  -fvisibility-inlines-hidden  -fmessage-length=0 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/mrera/anaconda3/envs/r4-base/include -fdebug-prefix-map=/home/builder/r-4.2.0/miniconda/envs/r-4.2.0/conda-bld/r-base_1653520836469/work=/usr/local/src/conda/r-base-4.2.0 -fdebug-prefix-map=/home/mrera/anaconda3/envs/r4-base=/usr/local/src/conda-prefix  -c file11443b52d5f71b.cpp -o file11443b52d5f71b.o
# Error in sourceCpp(code = model$cpp_code): Error 1 occurred building shared library.
# Traceback:
#
# 1. mk_model(characteristics = get_characteristics(pop), events = list(death_event,
#  .     swap_event), parameters = params)
# 2. sourceCpp(code = model$cpp_code)
# 3. stop("Error ", status, " occurred building shared library.")

# %%
pop
# Out:
#      birth death smurfness
# 1    0     NA    0
# 2    0     NA    0
# 3    0     NA    0
# 4    0     NA    0
# 5    0     NA    0
# 6    0     NA    0
# 7    0     NA    0
# 8    0     NA    0
# 9    0     NA    0
# 10   0     NA    0
# 11   0     NA    0
# 12   0     NA    0
# 13   0     NA    0
# 14   0     NA    0
# 15   0     NA    0
# 16   0     NA    0
# 17   0     NA    0
# 18   0     NA    0
# 19   0     NA    0
# 20   0     NA    0
# 21   0     NA    0
# 22   0     NA    0
# 23   0     NA    0
# 24   0     NA    0
# 25   0     NA    0
# 26   0     NA    0
# 27   0     NA    0
# 28   0     NA    0
# 29   0     NA    0
# 30   0     NA    0
# ...  ...   ...   ...
# 971  0     NA    0
# 972  0     NA    0
# 973  0     NA    0
# 974  0     NA    0
# 975  0     NA    0
# 976  0     NA    0
# 977  0     NA    0
# 978  0     NA    0
# 979  0     NA    0
# 980  0     NA    0
# 981  0     NA    0
# 982  0     NA    0
# 983  0     NA    0
# 984  0     NA    0
# 985  0     NA    0
# 986  0     NA    0
# 987  0     NA    0
# 988  0     NA    0
# 989  0     NA    0
# 990  0     NA    0
# 991  0     NA    0
# 992  0     NA    0
# 993  0     NA    0
# 994  0     NA    0
# 995  0     NA    0
# 996  0     NA    0
# 997  0     NA    0
# 998  0     NA    0
# 999  0     NA    0
# 1000 0     NA    0
