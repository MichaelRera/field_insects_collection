# %%
library(ggplot2)

# %%
N <- 10000
a <- 0.012
b <- -0.09
k <- 0.255
max_s_prop <- 0.7
age_max <- 70
pop <- matrix(,nrow=4,ncol=age_max)
rownames(pop)<-c("age","Smurf_prop","n_NS","n_S")
pop[1,]<- seq(0,age_max-1,1)

# %%
Smurf <- function(age){
    age_func <- a*age+b
    smurf_prop <- ifelse(age_func>0, ifelse(age_func<max_s_prop,runif(1,0,age_func*2),runif(1,0,max_s_prop)),0)
    return(smurf_prop)
    }

pop[3,1]<-N
for(i in pop[1,]){
    pop[2,i]<-Smurf(i)
}
pop[4,1]<-pop[3,1]*pop[2,1]
i=0
for(j in 2:length(pop[2,])){
   i=i+1 
   pop[3,j]<-pop[3,i]-pop[3,i]*pop[2,j] 
   pop[4,j]<-pop[3,i]*pop[2,j] 
}
pop<-pop[,-length(pop[1,])]

pop<-as.data.frame(t(pop))

# %%
age_max<-min(pop$age[which(pop$n_NS<1)])

# %%
ggplot(pop)+
    geom_line(aes(age,n_NS), linetype="dashed")+
    geom_line(aes(age,n_S), color="blue")+
    geom_line(aes(age,n_NS+n_S))+
    xlim(0,age_max)
# Out:
# Warning message:
# "Removed 27 row(s) containing missing values (geom_path)."Warning message:
# "Removed 27 row(s) containing missing values (geom_path)."Warning message:
# "Removed 27 row(s) containing missing values (geom_path)."
# plot without title

# %%
ggplot(pop)+
    geom_point(aes(x=age,y=n_S/(n_S+n_NS)), color="blue")+
    ylim(0,1)+
    xlim(0,age_max)
# Out:
# Warning message:
# "Removed 27 rows containing missing values (geom_point)."
# plot without title
